# %%
import torch

# %%
#testing device
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from transformers import BertTokenizer, BertModel
from PIL import Image
import json
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
#libs we used to accelerate the training process
# !pip install accelerate -U
# !pip install transformers[torch]
! pip install datasets
! pip install --upgrade tqdm
# !pip install pytorch-lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: accelerate in c:\users\harih\appdata\roaming\python\python311\site-packages (0.30.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\harih\appdata\roaming\python\python311\site-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in c:\programdata\anaconda3\lib\site-packages (from accelerate) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\programdata\anaconda3\lib\site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\harih\appdata\roaming\python\python311\site-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: intel-openmp==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.12.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harih\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub->accelerate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers[torch] in c:\programdata\anaconda3\lib\site-packages (4.40.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\harih\appdata\roaming\python\python311\site-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (2023.10.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\harih\appdata\roaming\python\python311\site-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in c:\users\harih\appdata\roaming\python\python311\site-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from transformers[torch]) (0.30.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harih\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\programdata\anaconda3\lib\site-packages (from torch->transformers[torch]) (2021.4.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers[torch]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harih\appdata\roaming\python\python311\site-packages (from requests->transformers[torch]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->transformers[torch]) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->transformers[torch]) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in c:\users\harih\appdata\roaming\python\python311\site-packages (2.19.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\harih\appdata\roaming\python\python311\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harih\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harih\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in c:\users\harih\appdata\roaming\python\python311\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytorch-lightning in c:\users\harih\appdata\roaming\python\python311\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torch>=1.13.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (2.3.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in c:\programdata\anaconda3\lib\site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2023.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from pytorch-lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\harih\appdata\roaming\python\python311\site-packages (from pytorch-lightning) (0.11.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->pytorch-lightning) (69.5.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13.0->pytorch-lightning) (3.13.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13.0->pytorch-lightning) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13.0->pytorch-lightning) (2021.4.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.57.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.3)
# Requirement already satisfied: intel-openmp==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->pytorch-lightning) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\programdata\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13.0->pytorch-lightning) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.13.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harih\appdata\roaming\python\python311\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.13.0->pytorch-lightning) (1.3.0)

# %%
# Defining ResNet model for image feature extraction
resnet = models.resnet152(pretrained=True)
resnet.fc = nn.Identity()  # Removing final fully connected layer to extract the features
#resnet.eval()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
hierarchy = {

}

# %%
from langdetect import detect_langs, DetectorFactory
from googletrans import Translator

def detect_and_translate(text):
    try:
        # Detect the language of the text
        detected_langs = detect_langs(text)
        detected_lang = detected_langs[0].lang
        detected_prob = detected_langs[0].prob
        
        # If the detected language is not English and has high enough probability, translate it
        if detected_lang != 'en' and detected_prob > 0.5:
            translator = Translator()
            translated_text = translator.translate(text, src=detected_lang, dest='en').text
            return translated_text
        else:
            return text
    except:
        # If language detection fails or probability is too low, return original text
        return text

# Example usage
text_to_translate = "¡Hola! ¿Cómo estás?"
translated_text = detect_and_translate(text_to_translate)
print(translated_text)
# Out:
# Hello!How are you?

# %%
# Defining the dataset class
class MemeDataset_T(Dataset):
    def __init__(self, image_dir, annotation_file, tokenizer, label_mapping, transform=None):
        self.image_dir = image_dir
        with open(annotation_file, 'r', encoding='utf-8') as f:
            self.data = json.load(f)
        self.tokenizer = tokenizer
        self.label_mapping = label_mapping  # Dictionary mapping label names to indices
        self.transform = transform or transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = os.path.join(self.image_dir, item['image'])
        image = Image.open(image_path).convert('RGB')
        image = self.transform(image)
        text = item['text']
        inputs = self.tokenizer(text, return_tensors="pt", max_length=512, truncation=True, padding="max_length")
        input_ids = inputs['input_ids'].squeeze(0)
        attention_mask = inputs['attention_mask'].squeeze(0)

        # Convert labels to indices and then to a tensor
        label_indices = [self.label_mapping[label] for label in item['labels']]
        labels = torch.zeros(len(self.label_mapping))
        labels[label_indices] = 1  # One-hot encoding of labels

        return image, input_ids, attention_mask, labels

# %%
# Defining the dataset class
class MemeDataset_V(Dataset):
    def __init__(self, image_dir, annotation_file, tokenizer, label_mapping, transform=None):
        self.image_dir = image_dir
        with open(annotation_file, 'r', encoding='utf-8') as f:
            self.data = json.load(f)
        self.tokenizer = tokenizer
        self.label_mapping = label_mapping  # Dictionary mapping label names to indices
        self.transform = transform or transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = os.path.join(self.image_dir, item['image'])
        image = Image.open(image_path).convert('RGB')
        image = self.transform(image)
        text = detect_and_translate(item['text'])
        inputs = self.tokenizer(text, return_tensors="pt", max_length=512, truncation=True, padding="max_length")
        input_ids = inputs['input_ids'].squeeze(0)
        attention_mask = inputs['attention_mask'].squeeze(0)

        # Convert labels to indices and then to a tensor
        label_indices = [self.label_mapping[label] for label in item['labels']]
        labels = torch.zeros(len(self.label_mapping))
        labels[label_indices] = 1  # One-hot encoding of labels

        return image, input_ids, attention_mask, labels

# %%
class MemeClassifier(nn.Module):
    def __init__(self, text_model, num_labels):
        super(MemeClassifier, self).__init__()
        self.text_model = text_model
        self.image_model = resnet
        self.classifier = nn.Linear(self.text_model.config.hidden_size + 2048, num_labels)

    def forward(self, images, input_ids, attention_mask):
        with torch.no_grad():
            image_features = self.image_model(images)
        text_features = self.text_model(input_ids=input_ids, attention_mask=attention_mask).pooler_output
        combined_features = torch.cat((text_features, image_features), dim=1)
        logits = self.classifier(combined_features)
        return logits

# %%
from sklearn.metrics import accuracy_score

def evaluate(model, data_loader, device, label_mapping):
    #print(model.eval())
    all_preds = []
    all_labels = []
    all_images = []  # Assuming you want to print images as well
    with torch.no_grad():
        for images, input_ids, attention_mask, labels in data_loader:
            #print("Labels is ",labels)
            images, input_ids, attention_mask, labels = images.to(device), input_ids.to(device), attention_mask.to(device), labels.to(device)
            logits = model(images, input_ids, attention_mask)
            #print("Logits is ",logits,"\n")
            predictions = torch.sigmoid(logits).round()  # Threshold at 0.5
            #print("Prediction is",predictions)
            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_images.extend(images)  # Append images or inputs if needed

    # Print predicted and actual labels
    correct = 0
    totalCount = 0
    for i in range(len(all_preds)):
        #print("All preds[i] is ",all_preds[i])
        predicted_labels = [label_mapping.get(j, 'Unknown') for j, label in enumerate(all_preds[i]) if label == 1]
        actual_labels = [label_mapping.get(j, 'Unknown') for j, label in enumerate(all_labels[i]) if label == 1]
        #actual_labels = [label_mapping[j] for j, label in enumerate(all_labels[i]) if label == 1]
        print("Predicted labels:", predicted_labels)
        print("Actual labels:", actual_labels)
        
        #correct = 0
        totalCount = totalCount + 1
        justCount = 0
    
        for j in actual_labels:
            if j in predicted_labels:
                justCount = justCount + 1

        if justCount >= len(actual_labels)/2:
            correct = correct + 1

    # Calculate manual accuracy checking the predicted labels correctly matching the true labels atleast half or more
    manual_accuracy = (correct / totalCount) * 100
    print("Manual Accuracy:", manual_accuracy)
    # Calculate hierarchical F1 score and accuracy
    h_f1 = hierarchical_f1_score(all_labels, all_preds, persuasion_hierarchy)
    accuracy = accuracy_score(all_labels, all_preds)
    print(f"Hierarchical F1 Score: {h_f1}")
    print(f"Accuracy: {accuracy}")
    #print("Accuracy manual is ",(correct/totalCount)*100) 

    return h_f1, accuracy

# %%
# Defining the hierarchy of persuasion techniques based on the provided image
persuasion_hierarchy = {
    'Persuasion': ['Ethos', 'Pathos', 'Logos'],
    'Ethos': ['Ad Hominem', 'Bandwagon', 'Appeal to Authority', 'Glittering Generalities', 'Transfer'],
    'Pathos': ['Appeal to Emotion', 'Exaggeration', 'Loaded Language', 'Flag Waving', 'Appeal to Fear', 'Transfer'],
    'Logos': ['Justification', 'Reasoning', 'Repetition', 'Intentional Vagueness'],
    'Ad Hominem': ['Name Calling', 'Doubt', 'Smears', 'Reductio ad Hitlerum', 'Whataboutism'],
    'Justification': ['Bandwagon', 'Appeal to Authority', 'Flag Waving', 'Appeal to Fear', 'Slogans'],
    'Reasoning': ['Distraction', 'Simplification'],
    'Distraction': ['Straw Man', 'Red Herring', 'Whataboutism'],
    'Simplification': ['Causal Oversimplification', 'Black & White Fallacy', 'Thought Terminating Cliche'],
}

# %%
# Function to get all ancestors of a technique in the hierarchy
def get_ancestors(technique, hierarchy):
    ancestors = []
    for parent, children in hierarchy.items():
        if technique in children:
            ancestors.append(parent)
            ancestors.extend(get_ancestors(parent, hierarchy))
    return ancestors

# %%
def hierarchical_f1_score(y_true, y_pred, hierarchy):
    """ Calculate the hierarchical F1 score considering the class hierarchy. """
    # Flattening the true and predicted labels to include their ancestors
    y_true_flat = [ancestor for label_set in y_true for label in label_set for ancestor in get_ancestors(label, hierarchy) + [label]]
    y_pred_flat = [ancestor for label_set in y_pred for label in label_set for ancestor in get_ancestors(label, hierarchy) + [label]]

    # Calculating F1 score
    f1 = f1_score(y_true_flat, y_pred_flat, average='micro')
    return f1

# %%
def create_label_mapping(annotation_file):
    all_labels = set()
    with open(annotation_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        for item in data:
            all_labels.update(item['labels'])
    return {label: i for i, label in enumerate(sorted(all_labels))}

# %%
def save_model(model, path):
    torch.save(model.state_dict(), path)
    print(f"Model saved to {path}")

# %%
def load_model(model, path):
    model.load_state_dict(torch.load(path))
    model.eval()  # Set the model to evaluation mode
    print("Model loaded and set to evaluation mode")

# %%
def load_annotation_data(annotation_file):
    with open(annotation_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

# %%
from tqdm import tqdm

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Device:", device)
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    text_model = BertModel.from_pretrained('bert-base-uncased')

    # Please provide your own paths to train our model if necessary
    image_dir = 'C:\\Users\\harih\\Downloads\\27\\train_images\\train_images'
    annotation_file = 'C:\\Users\\harih\\Downloads\\27\\semeval2024_dev_release\\semeval2024_dev_release\\subtask2a\\preprocessed_train_v2.json'
    label_mapping = create_label_mapping(annotation_file)
    print("Label mapping is ", label_mapping)

    train_dataset = MemeDataset_T(image_dir, annotation_file, tokenizer, label_mapping)
    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

    print("Train Loader:", train_loader)

    # Kindly validate with json with labels 
    #labels are used only for checking purpose
    val_image_dir = 'C:\\Users\\harih\\Downloads\\27\\train_images\\dev_images'
    val_annotation_file = 'C:\\Users\\harih\\Downloads\\27\\semeval2024_dev_release\\semeval2024_dev_release\\subtask2a\\dev_subtask2a_en.json'
    val_dataset = MemeDataset_V(val_image_dir, val_annotation_file, tokenizer, label_mapping)
    val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)

    print("Validation Loader:", val_loader)

    # Initialization of the model with the correct number of labels
    num_labels = 22  # Update this to reflect the correct number of unique labels
    model = MemeClassifier(BertModel.from_pretrained('bert-base-uncased'), num_labels).to(device)

    # Using optimizer and loss function here
    optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)
    criterion = nn.BCEWithLogitsLoss()

    # Updated training loop with tqdm
    model.train()
    num_epochs = 15  
    for epoch in range(num_epochs):
        total_loss = 0
        progress_bar = tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}', leave=False)
        for images, input_ids, attention_mask, labels in progress_bar:
            images, input_ids, attention_mask, labels = images.to(device), input_ids.to(device), attention_mask.to(device), labels.to(device)
            optimizer.zero_grad()
            logits = model(images, input_ids, attention_mask)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            progress_bar.set_postfix({'loss': total_loss / len(progress_bar)})  
        progress_bar.close()

    model_path = 'C:\\Users\\harih\\Downloads\\27\\meme_model_15f.pth'
    save_model(model, model_path)
    #evaluate(model, train_loader, device)
    #evaluate(model, val_loader, device)

    # Save the model after training
    
    save_model(model, model_path)

if __name__ == '__main__':
    main()
# Out:
# Device: cuda
# Label mapping is  {'Appeal to (Strong) Emotions': 0, 'Appeal to authority': 1, 'Appeal to fear/prejudice': 2, 'Bandwagon': 3, 'Black-and-white Fallacy/Dictatorship': 4, 'Causal Oversimplification': 5, 'Doubt': 6, 'Exaggeration/Minimisation': 7, 'Flag-waving': 8, 'Glittering generalities (Virtue)': 9, 'Loaded Language': 10, "Misrepresentation of Someone's Position (Straw Man)": 11, 'Name calling/Labeling': 12, 'Obfuscation, Intentional vagueness, Confusion': 13, 'Presenting Irrelevant Data (Red Herring)': 14, 'Reductio ad hitlerum': 15, 'Repetition': 16, 'Slogans': 17, 'Smears': 18, 'Thought-terminating cliché': 19, 'Transfer': 20, 'Whataboutism': 21}
# Train Loader: <torch.utils.data.dataloader.DataLoader object at 0x0000021AF758E1D0>
# Validation Loader: <torch.utils.data.dataloader.DataLoader object at 0x0000021AFBE03B50>
# Model saved to C:\Users\harih\Downloads\27\meme_model_15f.pth
# Model saved to C:\Users\harih\Downloads\27\meme_model_15f.pth

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
text_model = BertModel.from_pretrained('bert-base-uncased')
image_dir = 'C:\\Users\\harih\\Downloads\\27\\train_images\\train_images'
annotation_file = 'C:\\Users\\harih\\Downloads\\27\\semeval2024_dev_release\\semeval2024_dev_release\\subtask2a\\train.json'
label_mapping = create_label_mapping(annotation_file)
annotation_file = 'C:\\Users\\harih\\Downloads\\27\\semeval2024_dev_release\\semeval2024_dev_release\\subtask2a\\train.json'
print(label_mapping)
train_dataset = MemeDataset_T(image_dir, annotation_file, tokenizer, label_mapping)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
# Out:
# {'Appeal to (Strong) Emotions': 0, 'Appeal to authority': 1, 'Appeal to fear/prejudice': 2, 'Bandwagon': 3, 'Black-and-white Fallacy/Dictatorship': 4, 'Causal Oversimplification': 5, 'Doubt': 6, 'Exaggeration/Minimisation': 7, 'Flag-waving': 8, 'Glittering generalities (Virtue)': 9, 'Loaded Language': 10, "Misrepresentation of Someone's Position (Straw Man)": 11, 'Name calling/Labeling': 12, 'Obfuscation, Intentional vagueness, Confusion': 13, 'Presenting Irrelevant Data (Red Herring)': 14, 'Reductio ad hitlerum': 15, 'Repetition': 16, 'Slogans': 17, 'Smears': 18, 'Thought-terminating cliché': 19, 'Transfer': 20, 'Whataboutism': 21}

# %%
reversed_label_mapping = {v: k for k, v in label_mapping.items()}
print(reversed_label_mapping)
# Out:
# {0: 'Appeal to (Strong) Emotions', 1: 'Appeal to authority', 2: 'Appeal to fear/prejudice', 3: 'Bandwagon', 4: 'Black-and-white Fallacy/Dictatorship', 5: 'Causal Oversimplification', 6: 'Doubt', 7: 'Exaggeration/Minimisation', 8: 'Flag-waving', 9: 'Glittering generalities (Virtue)', 10: 'Loaded Language', 11: "Misrepresentation of Someone's Position (Straw Man)", 12: 'Name calling/Labeling', 13: 'Obfuscation, Intentional vagueness, Confusion', 14: 'Presenting Irrelevant Data (Red Herring)', 15: 'Reductio ad hitlerum', 16: 'Repetition', 17: 'Slogans', 18: 'Smears', 19: 'Thought-terminating cliché', 20: 'Transfer', 21: 'Whataboutism'}

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Defining the model architecture
model = MemeClassifier(BertModel.from_pretrained('bert-base-uncased'), 22)

# Load the model's state_dict
model_state_dict = torch.load('C:\\Users\\harih\\Downloads\\27\\meme_model_15f.pth', map_location=device)

# Move the model parameters to the correct device
model.load_state_dict(model_state_dict)
model.to(device)

# Changing the model into evaluation mode
model.eval()

# Now Proceeding with evaluation
evaluate(model, train_loader, device, reversed_label_mapping)

# %%
val_image_dir = 'C:\\Users\\harih\\Downloads\\27\\dev_images\\dev_images'
val_annotation_file = 'C:\\Users\\harih\\Downloads\\27\\semeval2024_dev_release\\semeval2024_dev_release\\subtask2a\\dev_subtask2a_en.json'
val_dataset = MemeDataset_T(val_image_dir, val_annotation_file, tokenizer, label_mapping)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)

# %%
print(val_loader)
evaluate(model, val_loader, device, reversed_label_mapping)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000021AFD69D510>
# Predicted labels: []
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Smears']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification']
# Predicted labels: ['Name calling/Labeling', 'Reductio ad hitlerum', 'Smears']
# Actual labels: ['Loaded Language', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification', 'Flag-waving', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Repetition']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Doubt', 'Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Thought-terminating cliché']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Slogans']
# Predicted labels: ['Smears', 'Thought-terminating cliché']
# Actual labels: ['Appeal to (Strong) Emotions', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Appeal to authority', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Repetition', 'Smears']
# Actual labels: ['Doubt', 'Transfer']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Causal Oversimplification']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Slogans']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Glittering generalities (Virtue)', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Slogans']
# Actual labels: ['Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Slogans']
# Predicted labels: ['Bandwagon', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Bandwagon', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Predicted labels: ['Loaded Language', 'Repetition', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Actual labels: ['Appeal to authority', 'Slogans']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Doubt', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Repetition', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Flag-waving', 'Repetition', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving', 'Name calling/Labeling', 'Repetition']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Loaded Language', 'Reductio ad hitlerum', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Doubt', 'Glittering generalities (Virtue)']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Flag-waving', 'Glittering generalities (Virtue)', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Whataboutism']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to authority', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Reductio ad hitlerum', 'Smears']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Smears']
# Actual labels: ['Flag-waving', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to authority', 'Appeal to fear/prejudice', 'Causal Oversimplification', 'Loaded Language']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Loaded Language', 'Slogans']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving', 'Loaded Language']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans', 'Smears', 'Thought-terminating cliché']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Thought-terminating cliché']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Exaggeration/Minimisation', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Bandwagon']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Slogans']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Flag-waving', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Loaded Language', 'Repetition']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Slogans']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Appeal to authority', 'Exaggeration/Minimisation', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Bandwagon', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Thought-terminating cliché']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Repetition', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Glittering generalities (Virtue)', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Doubt']
# Predicted labels: ['Slogans']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Bandwagon', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Doubt', 'Whataboutism']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears', 'Whataboutism']
# Actual labels: ['Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: []
# Actual labels: ['Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', 'Glittering generalities (Virtue)']
# Predicted labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Glittering generalities (Virtue)', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Repetition', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Doubt', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Slogans']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Appeal to authority', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Repetition', 'Smears']
# Predicted labels: ['Loaded Language', 'Transfer']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Transfer']
# Predicted labels: []
# Actual labels: ['Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Slogans', 'Thought-terminating cliché']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Repetition', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Repetition', 'Smears', 'Transfer']
# Predicted labels: ['Bandwagon']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Causal Oversimplification', 'Glittering generalities (Virtue)', 'Repetition']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Smears', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Transfer']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Doubt']
# Predicted labels: ['Loaded Language', 'Smears', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Smears', 'Whataboutism']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Glittering generalities (Virtue)', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Slogans']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Doubt', 'Thought-terminating cliché']
# Predicted labels: ['Flag-waving', 'Glittering generalities (Virtue)', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Glittering generalities (Virtue)', 'Loaded Language']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Thought-terminating cliché']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Flag-waving', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Actual labels: ['Appeal to authority', 'Flag-waving', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Causal Oversimplification', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Bandwagon', 'Flag-waving']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to authority']
# Actual labels: ['Appeal to authority', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Actual labels: ['Appeal to authority', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Slogans']
# Actual labels: ['Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears', 'Thought-terminating cliché']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Reductio ad hitlerum', 'Transfer']
# Predicted labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Slogans']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Repetition', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Doubt']
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to authority', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Loaded Language']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)']
# Predicted labels: []
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion', 'Thought-terminating cliché']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears', 'Whataboutism']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Repetition']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Loaded Language', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Slogans', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Whataboutism']
# Actual labels: ['Causal Oversimplification']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Flag-waving', 'Transfer']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans']
# Predicted labels: ['Obfuscation, Intentional vagueness, Confusion', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Reductio ad hitlerum']
# Predicted labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Loaded Language', 'Transfer']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Appeal to authority', 'Loaded Language', 'Repetition', 'Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Loaded Language', 'Name calling/Labeling', 'Repetition', 'Slogans']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Bandwagon', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Bandwagon', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Bandwagon']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Bandwagon', 'Flag-waving']
# Actual labels: ['Flag-waving', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Repetition', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Exaggeration/Minimisation', 'Slogans']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Flag-waving', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Reductio ad hitlerum', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Doubt', 'Transfer']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Doubt']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Doubt']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Bandwagon', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Loaded Language', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship', 'Causal Oversimplification', 'Glittering generalities (Virtue)', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Causal Oversimplification', 'Exaggeration/Minimisation', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Flag-waving']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Slogans', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Obfuscation, Intentional vagueness, Confusion']
# Actual labels: ['Loaded Language', 'Slogans']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt', 'Smears', 'Whataboutism']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to authority', 'Causal Oversimplification', 'Exaggeration/Minimisation', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Causal Oversimplification', 'Loaded Language']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Obfuscation, Intentional vagueness, Confusion', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Loaded Language']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Repetition', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Repetition', 'Whataboutism']
# Predicted labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Causal Oversimplification', 'Loaded Language', 'Repetition', 'Transfer']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Appeal to (Strong) Emotions', 'Slogans', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Repetition', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears', 'Transfer']
# Actual labels: ['Bandwagon', 'Black-and-white Fallacy/Dictatorship', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt', 'Smears']
# Actual labels: ['Doubt', 'Thought-terminating cliché', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Thought-terminating cliché']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Slogans']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Bandwagon', 'Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Repetition', 'Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Doubt']
# Actual labels: ['Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Flag-waving']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Reductio ad hitlerum', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Presenting Irrelevant Data (Red Herring)', 'Slogans', 'Smears']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Doubt', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Reductio ad hitlerum', 'Transfer']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Flag-waving', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Slogans']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Appeal to authority', 'Appeal to fear/prejudice']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Doubt', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Slogans']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Flag-waving', 'Slogans']
# Actual labels: ['Slogans', 'Transfer']
# Predicted labels: []
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Flag-waving', 'Smears']
# Actual labels: ['Bandwagon', 'Exaggeration/Minimisation']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Bandwagon', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Exaggeration/Minimisation', 'Flag-waving']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', 'Slogans', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# ...
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Whataboutism']
# Predicted labels: ['Appeal to fear/prejudice', 'Slogans', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Slogans']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Flag-waving']
# Predicted labels: ['Doubt', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Loaded Language', 'Slogans']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Slogans']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Slogans', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Slogans']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Bandwagon', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Transfer']
# Predicted labels: ['Doubt', 'Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Smears']
# Predicted labels: ['Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Slogans', 'Thought-terminating cliché']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Slogans', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Flag-waving', 'Glittering generalities (Virtue)', 'Loaded Language', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Presenting Irrelevant Data (Red Herring)', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Whataboutism']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Causal Oversimplification', 'Exaggeration/Minimisation', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Glittering generalities (Virtue)', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Bandwagon', 'Black-and-white Fallacy/Dictatorship', 'Flag-waving']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Exaggeration/Minimisation', 'Loaded Language', 'Transfer', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Flag-waving', 'Slogans']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Reductio ad hitlerum']
# Predicted labels: []
# Actual labels: ['Causal Oversimplification', 'Flag-waving', 'Glittering generalities (Virtue)']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Slogans']
# Actual labels: ['Glittering generalities (Virtue)', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Repetition', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Slogans']
# Actual labels: ['Loaded Language', 'Thought-terminating cliché']
# Predicted labels: []
# Actual labels: ['Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Smears']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Flag-waving', 'Name calling/Labeling']
# Predicted labels: ['Flag-waving', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Exaggeration/Minimisation', 'Glittering generalities (Virtue)', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Exaggeration/Minimisation', 'Glittering generalities (Virtue)', 'Loaded Language', 'Name calling/Labeling', 'Slogans', 'Thought-terminating cliché']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Slogans']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Repetition', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion', 'Transfer']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Bandwagon', 'Glittering generalities (Virtue)', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: []
# Actual labels: ['Doubt', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Flag-waving', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Repetition', 'Whataboutism']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Doubt', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Repetition', 'Smears']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Causal Oversimplification', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Bandwagon', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Flag-waving', 'Glittering generalities (Virtue)', 'Name calling/Labeling']
# Actual labels: ['Flag-waving', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Repetition', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Repetition', 'Smears']
# Predicted labels: ['Doubt']
# Actual labels: ['Doubt', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Doubt', 'Loaded Language', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Flag-waving']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Exaggeration/Minimisation', 'Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Name calling/Labeling', 'Smears', 'Transfer', 'Whataboutism']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Transfer']
# Actual labels: ['Slogans', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Whataboutism']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Obfuscation, Intentional vagueness, Confusion', 'Thought-terminating cliché']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Repetition', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification', 'Name calling/Labeling', 'Repetition', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Glittering generalities (Virtue)', 'Thought-terminating cliché']
# Predicted labels: ['Doubt', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Slogans', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', 'Glittering generalities (Virtue)', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Appeal to authority', 'Flag-waving', 'Smears']
# Actual labels: ['Appeal to authority', 'Flag-waving', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Manual Accuracy: 52.800000000000004
# Hierarchical F1 Score: 0.8943636363636364
# Accuracy: 0.104
# (0.8943636363636364, 0.104)

# %%
#!pip install langdetect googletrans==4.0.0-rc1

# %%
#testing
text_to_translate = "Нещата започват да излизат извън\nконтрол!!"
translated_text = detect_and_translate(text_to_translate)
print(translated_text)
# Out:
# Things are starting to go beyond
# Control !!

# %%
arabic_image_dir = 'C:\\Users\\harih\\Downloads\\multi_lang\\arabic_images\\test_images_arabic\\subtask2a'
arabic_annotation_file = 'C:\\Users\\harih\\Downloads\\multi_lang\\gold_multi\\test_subtask2a_ar.json'
arabic_dataset = MemeDataset_V(arabic_image_dir, arabic_annotation_file, tokenizer, label_mapping)
arabic_loader = DataLoader(arabic_dataset, batch_size=4, shuffle=False)

# %%
evaluate(model, arabic_loader, device, reversed_label_mapping)
# Out:
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Exaggeration/Minimisation', 'Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Thought-terminating cliché']
# Actual labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Flag-waving', 'Thought-terminating cliché']
# Actual labels: ['Doubt', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions']
# Actual labels: ['Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: []
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears', 'Whataboutism']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Exaggeration/Minimisation']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Doubt', 'Loaded Language']
# Actual labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Glittering generalities (Virtue)', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Name calling/Labeling']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship']
# Actual labels: []
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Thought-terminating cliché']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Transfer']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: []
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: []
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Loaded Language', 'Slogans']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Bandwagon', 'Smears']
# Actual labels: ['Bandwagon']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Repetition']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language']
# Predicted labels: ['Transfer']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language']
# Manual Accuracy: 34.166666666666664
# Hierarchical F1 Score: 0.8871212121212121
# Accuracy: 0.041666666666666664
# (0.8871212121212121, 0.041666666666666664)

# %%
bulgarian_image_dir = 'C:\\Users\\harih\\Downloads\\multi_lang\\multi_images\\test_images\\subtask1_2a\\bulgarian'
bulgarian_annotation_file = 'C:\\Users\\harih\\Downloads\\multi_lang\\gold_multi\\test_subtask2a_bg.json'
bulgarian_dataset = MemeDataset_V(bulgarian_image_dir, bulgarian_annotation_file, tokenizer, label_mapping)
bulgarian_loader = DataLoader(arabic_dataset, batch_size=4, shuffle=False)

# %%
evaluate(model, bulgarian_loader, device, reversed_label_mapping)
# Out:
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Exaggeration/Minimisation', 'Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Thought-terminating cliché']
# Actual labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Flag-waving', 'Thought-terminating cliché']
# Actual labels: ['Doubt', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions']
# Actual labels: ['Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: []
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears', 'Whataboutism']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Exaggeration/Minimisation']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Doubt', 'Loaded Language']
# Actual labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Glittering generalities (Virtue)', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: ['Name calling/Labeling']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship']
# Actual labels: []
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Thought-terminating cliché']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Doubt', 'Loaded Language', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Presenting Irrelevant Data (Red Herring)']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Transfer']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: []
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: []
# Predicted labels: ['Appeal to authority', 'Smears']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to authority']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Loaded Language', 'Slogans']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Bandwagon', 'Smears']
# Actual labels: ['Bandwagon']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Glittering generalities (Virtue)']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Repetition']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Glittering generalities (Virtue)']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language']
# Predicted labels: ['Transfer']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language']
# Manual Accuracy: 34.166666666666664
# Hierarchical F1 Score: 0.8871212121212121
# Accuracy: 0.041666666666666664
# (0.8871212121212121, 0.041666666666666664)

# %%
macedonian_image_dir = 'C:\\Users\\harih\\Downloads\\multi_lang\\multi_images\\test_images\\subtask1_2a\\north_macedonian'
macedonian_annotation_file = 'C:\\Users\\harih\\Downloads\\multi_lang\\gold_multi\\test_subtask2a_md.json'
macedonian_dataset = MemeDataset_V(macedonian_image_dir, macedonian_annotation_file, tokenizer, label_mapping)
macedonian_loader = DataLoader(macedonian_dataset, batch_size=4, shuffle=False)

# %%
evaluate(model, macedonian_loader, device, reversed_label_mapping)
# Out:
# Predicted labels: ['Appeal to fear/prejudice']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Slogans', 'Smears']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Flag-waving', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', "Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Flag-waving', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling']
# Predicted labels: ['Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Transfer']
# Actual labels: []
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Exaggeration/Minimisation', "Misrepresentation of Someone's Position (Straw Man)", 'Smears', 'Transfer']
# Predicted labels: ['Doubt']
# Actual labels: ['Repetition', 'Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Slogans', 'Smears']
# Actual labels: ['Appeal to authority', 'Exaggeration/Minimisation', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears', 'Transfer', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Reductio ad hitlerum', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Doubt', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Flag-waving', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to fear/prejudice', "Misrepresentation of Someone's Position (Straw Man)", 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Doubt']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer', 'Whataboutism']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Causal Oversimplification', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to authority', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Thought-terminating cliché']
# Predicted labels: ['Appeal to fear/prejudice', 'Doubt', 'Loaded Language', 'Name calling/Labeling', 'Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Presenting Irrelevant Data (Red Herring)', 'Smears']
# Actual labels: ['Doubt', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Slogans', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Obfuscation, Intentional vagueness, Confusion', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Smears', 'Whataboutism']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Predicted labels: []
# Actual labels: ['Presenting Irrelevant Data (Red Herring)', 'Slogans']
# Predicted labels: ['Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Doubt', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation']
# Predicted labels: ['Flag-waving', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears', 'Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt', 'Flag-waving', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: ['Bandwagon', 'Loaded Language', 'Slogans']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Slogans', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Repetition', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer', 'Whataboutism']
# Predicted labels: []
# Actual labels: ['Doubt', 'Loaded Language', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship']
# Actual labels: ['Appeal to (Strong) Emotions', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Exaggeration/Minimisation', 'Loaded Language']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Slogans']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Transfer']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Whataboutism']
# Predicted labels: ['Appeal to fear/prejudice', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Loaded Language']
# Predicted labels: ['Loaded Language', 'Repetition', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Flag-waving', 'Loaded Language', 'Repetition', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Slogans', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language']
# Actual labels: ['Loaded Language', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice']
# Predicted labels: ['Smears']
# Actual labels: ['Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Loaded Language', 'Slogans', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Repetition', 'Smears']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Repetition', 'Transfer']
# Actual labels: ['Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation']
# Actual labels: ['Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Flag-waving', 'Glittering generalities (Virtue)', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to authority', 'Glittering generalities (Virtue)', 'Transfer']
# Predicted labels: ['Transfer']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Reductio ad hitlerum', 'Smears', 'Transfer']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: ['Slogans', 'Transfer']
# Actual labels: ['Glittering generalities (Virtue)', 'Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Appeal to authority', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Flag-waving', 'Glittering generalities (Virtue)', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Transfer']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Slogans', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ["Misrepresentation of Someone's Position (Straw Man)", 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving', 'Name calling/Labeling', 'Transfer']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Doubt', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Smears', 'Transfer']
# Predicted labels: ['Exaggeration/Minimisation', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Transfer']
# Predicted labels: ['Appeal to (Strong) Emotions', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Loaded Language', 'Reductio ad hitlerum', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Glittering generalities (Virtue)', 'Loaded Language']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears', 'Transfer']
# Actual labels: []
# Predicted labels: ['Loaded Language', 'Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Actual labels: ['Causal Oversimplification', 'Exaggeration/Minimisation', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Slogans', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: []
# Predicted labels: ['Glittering generalities (Virtue)', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Transfer']
# Actual labels: ['Name calling/Labeling']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Smears', 'Whataboutism']
# Predicted labels: []
# Actual labels: ['Flag-waving', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Transfer']
# Actual labels: ['Smears', 'Whataboutism']
# Predicted labels: ['Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Doubt', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Causal Oversimplification', 'Loaded Language']
# Predicted labels: []
# Actual labels: ['Name calling/Labeling', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears', 'Transfer']
# Actual labels: ['Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: []
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Slogans', 'Smears', 'Transfer']
# Actual labels: ['Appeal to (Strong) Emotions', 'Loaded Language', 'Name calling/Labeling', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Slogans', 'Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', "Misrepresentation of Someone's Position (Straw Man)", 'Name calling/Labeling', 'Smears', 'Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: []
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Black-and-white Fallacy/Dictatorship', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Causal Oversimplification']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling']
# Predicted labels: ['Slogans', 'Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Exaggeration/Minimisation', 'Flag-waving', 'Smears']
# Predicted labels: []
# Actual labels: ['Loaded Language', 'Slogans', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Smears', 'Transfer']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Exaggeration/Minimisation', 'Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Name calling/Labeling', 'Repetition', 'Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Doubt', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: []
# Actual labels: ['Exaggeration/Minimisation', 'Slogans', 'Smears']
# Predicted labels: ['Appeal to authority', 'Glittering generalities (Virtue)']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to authority', 'Appeal to fear/prejudice', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Slogans', 'Smears']
# Predicted labels: []
# Actual labels: ['Doubt']
# Predicted labels: ['Slogans', 'Smears']
# Actual labels: ['Flag-waving', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears', 'Transfer']
# Actual labels: ['Name calling/Labeling', 'Smears', 'Transfer']
# Predicted labels: ['Smears']
# Actual labels: ['Appeal to (Strong) Emotions', 'Appeal to fear/prejudice', 'Exaggeration/Minimisation', 'Loaded Language', "Misrepresentation of Someone's Position (Straw Man)", 'Smears', 'Transfer']
# Predicted labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Smears']
# Actual labels: ['Appeal to authority', 'Appeal to fear/prejudice', 'Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Name calling/Labeling', 'Smears']
# Actual labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Predicted labels: ['Loaded Language', 'Smears']
# Actual labels: ['Doubt', 'Smears']
# Predicted labels: ['Smears']
# Actual labels: ['Thought-terminating cliché', 'Transfer']
# Predicted labels: ['Loaded Language', 'Name calling/Labeling', 'Smears']
# Actual labels: ['Exaggeration/Minimisation']
# Manual Accuracy: 40.54054054054054
# Hierarchical F1 Score: 0.8808353808353808
# Accuracy: 0.05791505791505792
# (0.8808353808353808, 0.05791505791505792)
